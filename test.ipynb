# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('data/dataset.csv')
df
# Out:
#      patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0       103368   53       1          2        171                0
# 1       119250   40       1          0         94              229
# 2       119372   49       1          2        133              142
# 3       132514   43       1          0        138              295
# 4       146211   31       1          1        199                0
# ..         ...  ...     ...        ...        ...              ...
# 995    9949544   48       1          2        139              349
# 996    9953423   47       1          3        143              258
# 997    9965859   69       1          0        156              434
# 998    9988507   45       1          1        186              417
# 999    9990855   25       1          0        158              270
#
#      fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                    0                1           147              0      5.3
# 1                    0                1           115              0      3.7
# 2                    0                0           202              1      5.0
# 3                    1                1           153              0      3.2
# 4                    0                2           136              0      5.3
# ..                 ...              ...           ...            ...      ...
# 995                  0                2           183              1      5.6
# 996                  1                1            98              1      5.7
# 997                  1                0           196              0      1.4
# 998                  0                1           117              1      5.9
# 999                  0                0           143              1      4.7
#
#      slope  noofmajorvessels  target
# 0        3                 3       1
# 1        1                 1       0
# 2        1                 0       0
# 3        2                 2       1
# 4        3                 2       1
# ..     ...               ...     ...
# 995      2                 2       1
# 996      1                 0       0
# 997      3                 1       1
# 998      3                 2       1
# 999      0                 0       0
#
# [1000 rows x 14 columns]

# %%
df.head().style.set_properties(**{'background-color':'blue','color':'white','border-color':'#8b8c8c'})
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   patientid          1000 non-null   int64
#  1   age                1000 non-null   int64
#  2   gender             1000 non-null   int64
#  3   chestpain          1000 non-null   int64
#  4   restingBP          1000 non-null   int64
#  5   serumcholestrol    1000 non-null   int64
#  6   fastingbloodsugar  1000 non-null   int64
#  7   restingrelectro    1000 non-null   int64
#  8   maxheartrate       1000 non-null   int64
#  9   exerciseangia      1000 non-null   int64
#  10  oldpeak            1000 non-null   float64
#  11  slope              1000 non-null   int64
#  12  noofmajorvessels   1000 non-null   int64
#  13  target             1000 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 109.5 KB

# %%
df.describe().T.style.background_gradient(axis=0)
# Out:
# <style type="text/css">
# #T_f34f2_row0_col0, #T_f34f2_row1_col0, #T_f34f2_row1_col1, #T_f34f2_row1_col2, #T_f34f2_row1_col3, #T_f34f2_row1_col4, #T_f34f2_row1_col5, #T_f34f2_row1_col6, #T_f34f2_row1_col7, #T_f34f2_row2_col0, #T_f34f2_row2_col1, #T_f34f2_row2_col2, #T_f34f2_row2_col3, #T_f34f2_row2_col4, #T_f34f2_row2_col5, #T_f34f2_row2_col6, #T_f34f2_row2_col7, #T_f34f2_row3_col0, #T_f34f2_row3_col1, #T_f34f2_row3_col2, #T_f34f2_row3_col3, #T_f34f2_row3_col4, #T_f34f2_row3_col5, #T_f34f2_row3_col6, #T_f34f2_row3_col7, #T_f34f2_row4_col0, #T_f34f2_row4_col1, #T_f34f2_row4_col2, #T_f34f2_row4_col3, #T_f34f2_row4_col4, #T_f34f2_row4_col5, #T_f34f2_row4_col6, #T_f34f2_row4_col7, #T_f34f2_row5_col0, #T_f34f2_row5_col1, #T_f34f2_row5_col2, #T_f34f2_row5_col3, #T_f34f2_row5_col4, #T_f34f2_row5_col5, #T_f34f2_row5_col6, #T_f34f2_row5_col7, #T_f34f2_row6_col0, #T_f34f2_row6_col1, #T_f34f2_row6_col2, #T_f34f2_row6_col3, #T_f34f2_row6_col4, #T_f34f2_row6_col5, #T_f34f2_row6_col6, #T_f34f2_row6_col7, #T_f34f2_row7_col0, #T_f34f2_row7_col1, #T_f34f2_row7_col2, #T_f34f2_row7_col3, #T_f34f2_row7_col4, #T_f34f2_row7_col5, #T_f34f2_row7_col6, #T_f34f2_row7_col7, #T_f34f2_row8_col0, #T_f34f2_row8_col1, #T_f34f2_row8_col2, #T_f34f2_row8_col3, #T_f34f2_row8_col4, #T_f34f2_row8_col5, #T_f34f2_row8_col6, #T_f34f2_row8_col7, #T_f34f2_row9_col0, #T_f34f2_row9_col1, #T_f34f2_row9_col2, #T_f34f2_row9_col3, #T_f34f2_row9_col4, #T_f34f2_row9_col5, #T_f34f2_row9_col6, #T_f34f2_row9_col7, #T_f34f2_row10_col0, #T_f34f2_row10_col1, #T_f34f2_row10_col2, #T_f34f2_row10_col3, #T_f34f2_row10_col4, #T_f34f2_row10_col5, #T_f34f2_row10_col6, #T_f34f2_row10_col7, #T_f34f2_row11_col0, #T_f34f2_row11_col1, #T_f34f2_row11_col2, #T_f34f2_row11_col3, #T_f34f2_row11_col4, #T_f34f2_row11_col5, #T_f34f2_row11_col6, #T_f34f2_row11_col7, #T_f34f2_row12_col0, #T_f34f2_row12_col1, #T_f34f2_row12_col2, #T_f34f2_row12_col3, #T_f34f2_row12_col4, #T_f34f2_row12_col5, #T_f34f2_row12_col6, #T_f34f2_row12_col7, #T_f34f2_row13_col0, #T_f34f2_row13_col1, #T_f34f2_row13_col2, #T_f34f2_row13_col3, #T_f34f2_row13_col4, #T_f34f2_row13_col5, #T_f34f2_row13_col6, #T_f34f2_row13_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_f34f2_row0_col1, #T_f34f2_row0_col2, #T_f34f2_row0_col3, #T_f34f2_row0_col4, #T_f34f2_row0_col5, #T_f34f2_row0_col6, #T_f34f2_row0_col7 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f34f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f34f2_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_f34f2_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_f34f2_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_f34f2_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_f34f2_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_f34f2_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_f34f2_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_f34f2_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f34f2_level0_row0" class="row_heading level0 row0" >patientid</th>
#       <td id="T_f34f2_row0_col0" class="data row0 col0" >1000.000000</td>
#       <td id="T_f34f2_row0_col1" class="data row0 col1" >5048704.412000</td>
#       <td id="T_f34f2_row0_col2" class="data row0 col2" >2895904.500488</td>
#       <td id="T_f34f2_row0_col3" class="data row0 col3" >103368.000000</td>
#       <td id="T_f34f2_row0_col4" class="data row0 col4" >2536439.500000</td>
#       <td id="T_f34f2_row0_col5" class="data row0 col5" >4952508.500000</td>
#       <td id="T_f34f2_row0_col6" class="data row0 col6" >7681877.000000</td>
#       <td id="T_f34f2_row0_col7" class="data row0 col7" >9990855.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f34f2_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_f34f2_row1_col0" class="data row1 col0" >1000.000000</td>
#       <td id="T_f34f2_row1_col1" class="data row1 col1" >49.242000</td>
#       <td id="T_f34f2_row1_col2" class="data row1 col2" >17.864730</td>
#       <td id="T_f34f2_row1_col3" class="data row1 col3" >20.000000</td>
#       <td id="T_f34f2_row1_col4" class="data row1 col4" >34.000000</td>
#       <td id="T_f34f2_row1_col5" class="data row1 col5" >49.000000</td>
#       <td id="T_f34f2_row1_col6" class="data row1 col6" >64.250000</td>
#       <td id="T_f34f2_row1_col7" class="data row1 col7" >80.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f34f2_level0_row2" class="row_heading level0 row2" >gender</th>
#       <td id="T_f34f2_row2_col0" class="data row2 col0" >1000.000000</td>
#       <td id="T_f34f2_row2_col1" class="data row2 col1" >0.765000</td>
#       <td id="T_f34f2_row2_col2" class="data row2 col2" >0.424211</td>
#       <td id="T_f34f2_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_f34f2_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_f34f2_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_f34f2_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_f34f2_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f34f2_level0_row3" class="row_heading level0 row3" >chestpain</th>
#       <td id="T_f34f2_row3_col0" class="data row3 col0" >1000.000000</td>
#       <td id="T_f34f2_row3_col1" class="data row3 col1" >0.980000</td>
#       <td id="T_f34f2_row3_col2" class="data row3 col2" >0.953157</td>
#       <td id="T_f34f2_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_f34f2_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_f34f2_row3_col5" class="data row3 col5" >1.000000</td>
#       <td id="T_f34f2_row3_col6" class="data row3 col6" >2.000000</td>
#       <td id="T_f34f2_row3_col7" class="data row3 col7" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f34f2_level0_row4" class="row_heading level0 row4" >restingBP</th>
#       <td id="T_f34f2_row4_col0" class="data row4 col0" >1000.000000</td>
#       <td id="T_f34f2_row4_col1" class="data row4 col1" >151.747000</td>
#       <td id="T_f34f2_row4_col2" class="data row4 col2" >29.965228</td>
#       <td id="T_f34f2_row4_col3" class="data row4 col3" >94.000000</td>
#       <td id="T_f34f2_row4_col4" class="data row4 col4" >129.000000</td>
#       <td id="T_f34f2_row4_col5" class="data row4 col5" >147.000000</td>
#       <td id="T_f34f2_row4_col6" class="data row4 col6" >181.000000</td>
#       <td id="T_f34f2_row4_col7" class="data row4 col7" >200.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f34f2_level0_row5" class="row_heading level0 row5" >serumcholestrol</th>
#       <td id="T_f34f2_row5_col0" class="data row5 col0" >1000.000000</td>
#       <td id="T_f34f2_row5_col1" class="data row5 col1" >311.447000</td>
#       <td id="T_f34f2_row5_col2" class="data row5 col2" >132.443801</td>
#       <td id="T_f34f2_row5_col3" class="data row5 col3" >0.000000</td>
#       <td id="T_f34f2_row5_col4" class="data row5 col4" >235.750000</td>
#       <td id="T_f34f2_row5_col5" class="data row5 col5" >318.000000</td>
#       <td id="T_f34f2_row5_col6" class="data row5 col6" >404.250000</td>
#       <td id="T_f34f2_row5_col7" class="data row5 col7" >602.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f34f2_level0_row6" class="row_heading level0 row6" >fastingbloodsugar</th>
#       <td id="T_f34f2_row6_col0" class="data row6 col0" >1000.000000</td>
#       <td id="T_f34f2_row6_col1" class="data row6 col1" >0.296000</td>
#       <td id="T_f34f2_row6_col2" class="data row6 col2" >0.456719</td>
#       <td id="T_f34f2_row6_col3" class="data row6 col3" >0.000000</td>
#       <td id="T_f34f2_row6_col4" class="data row6 col4" >0.000000</td>
#       <td id="T_f34f2_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_f34f2_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_f34f2_row6_col7" class="data row6 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_f34f2_level0_row7" class="row_heading level0 row

# %%
df.isna().sum()
# Out:
# patientid            0
# age                  0
# gender               0
# chestpain            0
# restingBP            0
# serumcholestrol      0
# fastingbloodsugar    0
# restingrelectro      0
# maxheartrate         0
# exerciseangia        0
# oldpeak              0
# slope                0
# noofmajorvessels     0
# target               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['patientid', 'age', 'gender', 'chestpain', 'restingBP',
#        'serumcholestrol', 'fastingbloodsugar', 'restingrelectro',
#        'maxheartrate', 'exerciseangia', 'oldpeak', 'slope', 'noofmajorvessels',
#        'target'],
#       dtype='object')

# %% [markdown]
# Analyse data

# %%
age_range = f"Age Range: {df['age'].min()} - {df['age'].max()}"
gender_count = df['gender'].value_counts()
chest_pain_counts = df['chestpain'].value_counts()
print(age_range)
print(gender_count)
print(chest_pain_counts)
# Out:
# Age Range: 20 - 80
# gender
# 1    765
# 0    235
# Name: count, dtype: int64
# chestpain
# 0    420
# 2    312
# 1    224
# 3     44
# Name: count, dtype: int64

# %%
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.barplot(x='chestpain', y='maxheartrate', data=df, palette='viridis')
plt.title('Maximum Heart Rate by Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.ylabel('Maximum Heart Rate')
plt.show()
# Out:
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
average_resting_bp = df['restingBP'].mean()
print(f"Average Resting Blood Pressure: {average_resting_bp:.2f} mm Hg")
# Out:
# Average Resting Blood Pressure: 151.75 mm Hg

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='serumcholestrol', data=df, palette='coolwarm')
plt.title('Distribution of Serum Cholesterol')
plt.xlabel('Serum Cholesterol')
plt.show()
# Out:
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
percentage_high_fasting_sugar = (df['fastingbloodsugar'].sum() / len(df)) * 100
print(f"Percentage of patients with fasting blood sugar > 120 mg/dl: {percentage_high_fasting_sugar:.2f}%")
resting_electro_counts = df['restingrelectro'].value_counts()
print(resting_electro_counts)
# Out:
# Percentage of patients with fasting blood sugar > 120 mg/dl: 29.60%
# restingrelectro
# 0    454
# 1    344
# 2    202
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='age', y='maxheartrate', hue='target', data=df, palette='coolwarm', s=100)
plt.title('Age vs. Max Heart Rate with Target Labels')
plt.xlabel('Age')
plt.ylabel('Max Heart Rate')
plt.legend(title='Target', loc='upper right', labels=['No Heart Disease', 'Heart Disease'])
plt.show()
# Out:
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
average_max_heart_rate = df['maxheartrate'].mean()
print(f"Average Maximum Heart Rate: {average_max_heart_rate:.2f}")
exercise_angina_count = df['exerciseangia'].sum()
print(f"Number of Patients with Exercise-Induced Angina: {exercise_angina_count}")
average_oldpeak = df['oldpeak'].mean()
print(f"Average Oldpeak: {average_oldpeak:.2f}")
# Out:
# Average Maximum Heart Rate: 145.48
# Number of Patients with Exercise-Induced Angina: 498
# Average Oldpeak: 2.71

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='slope', data=df, palette='viridis')
plt.title('Distribution of Slope of Peak Exercise ST Segment')
plt.xlabel('Slope')
plt.ylabel('Count')
plt.show()
# Out:
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
vessels_range = f"Number of Major Vessels Range: {df['noofmajorvessels'].min()} - {df['noofmajorvessels'].max()}"
print(vessels_range)

percentage_heart_disease = (df['target'].sum() / len(df)) * 100
print(f"Percentage of Patients with Heart Disease: {percentage_heart_disease:.2f}%")
# add percentage of female and men having heart discease
# Out:
# Number of Major Vessels Range: 0 - 3
# Percentage of Patients with Heart Disease: 58.00%

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='age', hue='gender', data=df, palette='muted', multiple='stack', bins=15)
plt.title('Age Distribution by Gender')
plt.xlabel('Age')
plt.ylabel('Count')
plt.legend(title='Gender', labels=['Female', 'Male'])
plt.show()
# Out:
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
oldest_patient = df.loc[df['age'].idxmax()]
print(f"Details of the Oldest Patient:\n{oldest_patient}")
lowest_bp_patient = df.loc[df['restingBP'].idxmin()]
print(f"Details of the Patient with the Lowest Resting Blood Pressure:\n{lowest_bp_patient}")
correlation_age_maxheartrate = df['age'].corr(df['maxheartrate'])
print(f"Correlation between Age and Maximum Heart Rate: {correlation_age_maxheartrate:.2f}")
# Out:
# Details of the Oldest Patient:
# patientid            1160678.0
# age                       80.0
# gender                     1.0
# chestpain                  1.0
# restingBP                130.0
# serumcholestrol          342.0
# fastingbloodsugar          0.0
# restingrelectro            0.0
# maxheartrate             176.0
# exerciseangia              1.0
# oldpeak                    2.5
# slope                      0.0
# noofmajorvessels           0.0
# target                     0.0
# Name: 102, dtype: float64
# Details of the Patient with the Lowest Resting Blood Pressure:
# patientid            119250.0
# age                      40.0
# gender                    1.0
# chestpain                 0.0
# restingBP                94.0
# serumcholestrol         229.0
# fastingbloodsugar         0.0
# restingrelectro           1.0
# maxheartrate            115.0
# exerciseangia             0.0
# oldpeak                   3.7
# slope                     1.0
# noofmajorvessels          1.0
# target                    0.0
# Name: 1, dtype: float64
# Correlation between Age and Maximum Heart Rate: -0.04

# %%
df['target'] = df['target'].astype(str)
plt.figure(figsize=(10, 6))
sns.countplot(x='chestpain', hue='target', data=df, palette='Set1')
plt.title('Heart Disease Presence by Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.ylabel('Count')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()
# Out:
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(10, 6))
sns.boxplot(x='target', y='serumcholestrol', data=df, palette='pastel')
plt.title('Serum Cholesterol Distribution by Heart Disease Presence')
plt.xlabel('Heart Disease Presence')
plt.ylabel('Serum Cholesterol')
plt.xticks(ticks=[0, 1], labels=['Heart Disease', 'No Heart Disease'])
plt.show()
# Out:
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %%
plt.figure(figsize=(10, 6))
sns.histplot(x='oldpeak', data=df[df['target'] == 1], bins=15, kde=True, color='coral')
plt.title('Distribution of Oldpeak in Patients with Heart Disease')
plt.xlabel('Oldpeak')
plt.ylabel('Count')
plt.show()

# %%
defects_count = len(df[df['noofmajorvessels'] == 3])
print(f"Number of Patients with Defects in All Three Major Vessels: {defects_count}")
# Out:
# Number of Patients with Defects in All Three Major Vessels: 116

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='gender', y='maxheartrate', hue='target', data=df, palette='mako')
plt.title('Max Heart Rate by Gender and Heart Disease Presence')
plt.xlabel('Gender')
plt.ylabel('Max Heart Rate')
plt.legend(title='Heart Disease', labels=['No', 'Yes'])
plt.show()
# Out:
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# /home/exa/anaconda3/envs/health/lib/python3.10/site-packages/seaborn/_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):

# %% [markdown]
# target categorizing

# %%
df.target.unique()
df = df.replace({'target' : {
                                    0 : 'Absence of Heart Disease',
                                    1 : 'Presence of Heart Disease',
        }}
)
df.head()
# Out:
#    patientid  age  gender  chestpain  restingBP  serumcholestrol  \
# 0     103368   53       1          2        171                0
# 1     119250   40       1          0         94              229
# 2     119372   49       1          2        133              142
# 3     132514   43       1          0        138              295
# 4     146211   31       1          1        199                0
#
#    fastingbloodsugar  restingrelectro  maxheartrate  exerciseangia  oldpeak  \
# 0                  0                1           147              0      5.3
# 1                  0                1           115              0      3.7
# 2                  0                0           202              1      5.0
# 3                  1                1           153              0      3.2
# 4                  0                2           136              0      5.3
#
#    slope  noofmajorvessels target
# 0      3                 3      1
# 1      1                 1      0
# 2      1                 0      0
# 3      2                 2      1
# 4      3                 2      1

# %% [markdown]
# normalisation

# %%
from sklearn.preprocessing import MinMaxScaler

# explain the normalisation why
X_disease = df.drop(columns='target')
y = df.target
scaler = MinMaxScaler(feature_range=(0, 1)).fit_transform(X_disease)
X = pd.DataFrame(scaler, columns=X_disease.columns)
X.describe().T.style.background_gradient(axis=0, cmap='plasma')
# Out:
# <style type="text/css">
# #T_a0fb5_row0_col0, #T_a0fb5_row0_col3, #T_a0fb5_row1_col0, #T_a0fb5_row1_col3, #T_a0fb5_row2_col0, #T_a0fb5_row2_col3, #T_a0fb5_row3_col0, #T_a0fb5_row3_col3, #T_a0fb5_row3_col4, #T_a0fb5_row4_col0, #T_a0fb5_row4_col3, #T_a0fb5_row5_col0, #T_a0fb5_row5_col2, #T_a0fb5_row5_col3, #T_a0fb5_row6_col0, #T_a0fb5_row6_col1, #T_a0fb5_row6_col3, #T_a0fb5_row6_col4, #T_a0fb5_row6_col5, #T_a0fb5_row7_col0, #T_a0fb5_row7_col3, #T_a0fb5_row7_col4, #T_a0fb5_row7_col6, #T_a0fb5_row8_col0, #T_a0fb5_row8_col3, #T_a0fb5_row8_col7, #T_a0fb5_row9_col0, #T_a0fb5_row9_col3, #T_a0fb5_row9_col4, #T_a0fb5_row9_col5, #T_a0fb5_row10_col0, #T_a0fb5_row10_col3, #T_a0fb5_row11_col0, #T_a0fb5_row11_col3, #T_a0fb5_row12_col0, #T_a0fb5_row12_col3, #T_a0fb5_row12_col4 {
#   background-color: #0d0887;
#   color: #f1f1f1;
# }
# #T_a0fb5_row0_col1 {
#   background-color: #bb3488;
#   color: #f1f1f1;
# }
# #T_a0fb5_row0_col2 {
#   background-color: #8104a7;
#   color: #f1f1f1;
# }
# #T_a0fb5_row0_col4 {
#   background-color: #7b02a8;
#   color: #f1f1f1;
# }
# #T_a0fb5_row0_col5 {
#   background-color: #c9447a;
#   color: #f1f1f1;
# }
# #T_a0fb5_row0_col6 {
#   background-color: #d35171;
#   color: #f1f1f1;
# }
# #T_a0fb5_row0_col7, #T_a0fb5_row2_col1, #T_a0fb5_row2_col4, #T_a0fb5_row2_col5, #T_a0fb5_row2_col6, #T_a0fb5_row6_col6, #T_a0fb5_row9_col2, #T_a0fb5_row9_col6 {
#   background-color: #f0f921;
#   color: #000000;
# }
# #T_a0fb5_row1_col1, #T_a0fb5_row11_col2 {
#   background-color: #b32c8e;
#   color: #f1f1f1;
# }
# #T_a0fb5_row1_col2 {
#   background-color: #8808a6;
#   color: #f1f1f1;
# }
# #T_a0fb5_row1_col4 {
#   background-color: #7701a8;
#   color: #f1f1f1;
# }
# #T_a0fb5_row1_col5 {
#   background-color: #c7427c;
#   color: #f1f1f1;
# }
# #T_a0fb5_row1_col6 {
#   background-color: #c5407e;
#   color: #f1f1f1;
# }
# #T_a0fb5_row1_col7, #T_a0fb5_row2_col7, #T_a0fb5_row3_col5, #T_a0fb5_row3_col6, #T_a0fb5_row3_col7, #T_a0fb5_row4_col7, #T_a0fb5_row5_col7, #T_a0fb5_row6_col7, #T_a0fb5_row7_col7, #T_a0fb5_row9_col7, #T_a0fb5_row10_col7, #T_a0fb5_row11_col4, #T_a0fb5_row11_col6, #T_a0fb5_row11_col7, #T_a0fb5_row12_col5, #T_a0fb5_row12_col6, #T_a0fb5_row12_col7 {
#   background-color: #9c179e;
#   color: #f1f1f1;
# }
# #T_a0fb5_row2_col2 {
#   background-color: #f68d45;
#   color: #f1f1f1;
# }
# #T_a0fb5_row3_col1 {
#   background-color: #310597;
#   color: #f1f1f1;
# }
# #T_a0fb5_row3_col2 {
#   background-color: #a11b9b;
#   color: #f1f1f1;
# }
# #T_a0fb5_row4_col1, #T_a0fb5_row5_col5 {
#   background-color: #d24f71;
#   color: #f1f1f1;
# }
# #T_a0fb5_row4_col2 {
#   background-color: #7401a8;
#   color: #f1f1f1;
# }
# #T_a0fb5_row4_col4 {
#   background-color: #9a169f;
#   color: #f1f1f1;
# }
# #T_a0fb5_row4_col5, #T_a0fb5_row7_col5 {
#   background-color: #cc4778;
#   color: #f1f1f1;
# }
# #T_a0fb5_row4_col6 {
#   background-color: #e97158;
#   color: #f1f1f1;
# }
# #T_a0fb5_row5_col1 {
#   background-color: #c43e7f;
#   color: #f1f1f1;
# }
# #T_a0fb5_row5_col4 {
#   background-color: #ae2892;
#   color: #f1f1f1;
# }
# #T_a0fb5_row5_col6 {
#   background-color: #9e199d;
#   color: #f1f1f1;
# }
# #T_a0fb5_row6_col2 {
#   background-color: #feb82c;
#   color: #000000;
# }
# #T_a0fb5_row7_col1 {
#   background-color: #5c01a6;
#   color: #f1f1f1;
# }
# #T_a0fb5_row7_col2, #T_a0fb5_row8_col6 {
#   background-color: #de6164;
#   color: #f1f1f1;
# }
# #T_a0fb5_row8_col1 {
#   background-color: #dd5e66;
#   color: #f1f1f1;
# }
# #T_a0fb5_row8_col2 {
#   background-color: #5502a4;
#   color: #f1f1f1;
# }
# #T_a0fb5_row8_col4 {
#   background-color: #a82296;
#   color: #f1f1f1;
# }
# #T_a0fb5_row8_col5 {
#   background-color: #db5c68;
#   color: #f1f1f1;
# }
# #T_a0fb5_row9_col1 {
#   background-color: #ba3388;
#   color: #f1f1f1;
# }
# #T_a0fb5_row10_col1 {
#   background-color: #8f0da4;
#   color: #f1f1f1;
# }
# #T_a0fb5_row10_col2 {
#   background-color: #6c00a8;
#   color: #f1f1f1;
# }
# #T_a0fb5_row10_col4 {
#   background-color: #6e00a8;
#   color: #f1f1f1;
# }
# #T_a0fb5_row10_col5 {
#   background-color: #ad2793;
#   color: #f1f1f1;
# }
# #T_a0fb5_row10_col6 {
#   background-color: #9814a0;
#   color: #f1f1f1;
# }
# #T_a0fb5_row11_col1 {
#   background-color: #c23c81;
#   color: #f1f1f1;
# }
# #T_a0fb5_row11_col5 {
#   background-color: #ed7953;
#   color: #f1f1f1;
# }
# #T_a0fb5_row12_col1 {
#   background-color: #7801a8;
#   color: #f1f1f1;
# }
# #T_a0fb5_row12_col2 {
#   background-color: #aa2395;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a0fb5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0fb5_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_a0fb5_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_a0fb5_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_a0fb5_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_a0fb5_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_a0fb5_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_a0fb5_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_a0fb5_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0fb5_level0_row0" class="row_heading level0 row0" >patientid</th>
#       <td id="T_a0fb5_row0_col0" class="data row0 col0" >1000.000000</td>
#       <td id="T_a0fb5_row0_col1" class="data row0 col1" >0.500161</td>
#       <td id="T_a0fb5_row0_col2" class="data row0 col2" >0.292886</td>
#       <td id="T_a0fb5_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_a0fb5_row0_col4" class="data row0 col4" >0.246076</td>
#       <td id="T_a0fb5_row0_col5" class="data row0 col5" >0.490432</td>
#       <td id="T_a0fb5_row0_col6" class="data row0 col6" >0.766475</td>
#       <td id="T_a0fb5_row0_col7" class="data row0 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a0fb5_level0_row1" class="row_heading level0 row1" >age</th>
#       <td id="T_a0fb5_row1_col0" class="data row1 col0" >1000.000000</td>
#       <td id="T_a0fb5_row1_col1" class="data row1 col1" >0.487367</td>
#       <td id="T_a0fb5_row1_col2" class="data row1 col2" >0.297746</td>
#       <td id="T_a0fb5_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_a0fb5_row1_col4" class="data row1 col4" >0.233333</td>
#       <td id="T_a0fb5_row1_col5" class="data row1 col5" >0.483333</td>
#       <td id="T_a0fb5_row1_col6" class="data row1 col6" >0.737500</td>
#       <td id="T_a0fb5_row1_col7" class="data row1 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a0fb5_level0_row2" class="row_heading level0 row2" >gender</th>
#       <td id="T_a0fb5_row2_col0" class="data row2 col0" >1000.000000</td>
#       <td id="T_a0fb5_row2_col1" class="data row2 col1" >0.765000</td>
#       <td id="T_a0fb5_row2_col2" class="data row2 col2" >0.424211</td>
#       <td id="T_a0fb5_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_a0fb5_row2_col4" class="data row2 col4" >1.000000</td>
#       <td id="T_a0fb5_row2_col5" class="data row2 col5" >1.000000</td>
#       <td id="T_a0fb5_row2_col6" class="data row2 col6" >1.000000</td>
#       <td id="T_a0fb5_row2_col7" class="data row2 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a0fb5_level0_row3" class="row_heading level0 row3" >chestpain</th>
#       <td id="T_a0fb5_row3_col0" class="data row3 col0" >1000.000000</td>
#       <td id="T_a0fb5_row3_col1" class="data row3 col1" >0.326667</td>
#       <td id="T_a0fb5_row3_col2" class="data row3 col2" >0.317719</td>
#       <td id="T_a0fb5_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_a0fb5_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_a0fb5_row3_col5" class="data row3 col5" >0.333333</td>
#       <td id="T_a0fb5_row3_col6" class="data row3 col6" >0.666667</td>
#       <td id="T_a0fb5_row3_col7" class="data row3 col7" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_a0fb5_level0_row4" class="row_heading level0 row4" >restingBP</th>
#       <td id="T_a0fb5_row4_col0" class="data row4 col0" >1000.000000</td>
#       <td id="T_a0fb5_row4_col1" class="data row4 col1" >0.544783</td>
#       <td id="T_a0fb5_row4_col2" class="data row4 col2" >0.282691</td>
#       <td id="T_a0fb5_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_a

# %% [markdown]
# modeling

# %%
from sklearn import metrics

def plot_confusion_matrix(y_test, y_prediction):
    '''Plotting Confusion Matrix'''
    cm = metrics.confusion_matrix(y_test, y_prediction)
    ax = plt.subplot()
    ax = sns.heatmap(cm, annot=True, fmt='', cmap="plasma")
    ax.set_xlabel('Predicted labels', fontsize=18)
    ax.set_ylabel('True labels', fontsize=18)
    ax.set_title('Confusion Matrix', fontsize=25)
    ax.xaxis.set_ticklabels(['Absence of Heart Disease','Presence of Heart Disease'])
    ax.yaxis.set_ticklabels(['Absence of Heart Disease','Presence of Heart Disease'])
    plt.show()

def clfr_plot(y_test, y_pred) :
    ''' Plotting Classification report'''
    cr = pd.DataFrame(metrics.classification_report(y_test, y_pred_rf, digits=3,
                                            output_dict=True)).T
    cr.drop(columns='support', inplace=True)
    sns.heatmap(cr, cmap='plasma', annot=True, linecolor='white', linewidths=0.5).xaxis.tick_top()

# %%
def clf_plot(y_pred) :
    '''
    1) Ploting Confusion Matrix
    2) Plotting Classification Report'''
    cm = metrics.confusion_matrix(y_test, y_pred)
    cr = pd.DataFrame(metrics.classification_report(y_test, y_pred, digits=3, output_dict=True)).T
    cr.drop(columns='support', inplace=True)

    fig, ax = plt.subplots(1, 2, figsize=(15, 5))

    # Left: Confusion Matrix
    ax[0] = sns.heatmap(cm, annot=True, fmt='', cmap="plasma", ax=ax[0])
    ax[0].set_xlabel('Predicted labels', fontsize=18)
    ax[0].set_ylabel('True labels', fontsize=18)
    ax[0].set_title('Confusion Matrix', fontsize=25)
    ax[0].xaxis.set_ticklabels(['Absence of Heart Disease','Presence of Heart Disease'])
    ax[0].yaxis.set_ticklabels(['Absence of Heart Disease','Presence of Heart Disease'])

    # Right: Classification Report
    ax[1] = sns.heatmap(cr, cmap='plasma', annot=True, linecolor='white', linewidths=0.5, ax=ax[1])
    ax[1].xaxis.tick_top()
    ax[1].set_title('Classification Report', fontsize=25)
    plt.show()
    
df.target.value_counts()
# Out:
# target
# 1    580
# 0    420
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score, KFold

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %% [markdown]
# R forest

# %%
from sklearn.ensemble import RandomForestClassifier

parameters = {
    'n_estimators' : [50, 150, 500],
    'criterion' : ['gini', 'entropy', 'log_loss'],
    'max_features' : ['sqrt', 'log2']
}

rf = RandomForestClassifier(n_jobs=-1)
rf_cv = GridSearchCV(estimator=rf, cv=20, param_grid=parameters).fit(X_train, y_train)

print('Tuned hyper parameters : ', rf_cv.best_params_)
print('accuracy : ', rf_cv.best_score_)
# Out:
# Tuned hyper parameters :  {'criterion': 'gini', 'max_features': 'sqrt', 'n_estimators': 50}
# accuracy :  0.9800142247510669

# %%
rf = RandomForestClassifier(**rf_cv.best_params_).fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

rf_score = round(rf.score(X_test, y_test), 3)
print('RandomForestClassifier score : ', rf_score)
# Out:
# RandomForestClassifier score :  0.976

# %%
y_test.value_counts()
clf_plot(y_pred_rf)

# %%
rf = RandomForestClassifier(**rf_cv.best_params_)
rf.fit(X, y)
# Out:
# RandomForestClassifier(n_estimators=50)
